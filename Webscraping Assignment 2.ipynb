# %% [markdown]
# # Assignment

# %%
# !pip install selenium
# !pip install --upgrade selenium

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# #### Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.shine.com/
# 2. Enter “Data Analyst” in “Job title, Skills” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the searchbutton.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
driver = webdriver.Chrome()

# %%
#opening the shine page on automated chrome browser
driver.get('https://www.shine.com/')

# %%
select=driver.find_element(By.CLASS_NAME,"input")
select.click()

# %%
#entering designation and location as required in the question

designation=driver.find_element(By.CLASS_NAME,"form-control  ")
designation.send_keys('Data Analyst')

# %% [markdown]
# ###### select=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[1]/div/ul/li[4]')
# select.click

# %%
cancel=driver.find_element(By.CLASS_NAME,"styledcls_body_hidden")
cancel.click()

# %%
location =driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input')
location.send_keys('Bangalore')

# %% [markdown]
# ###### Experience =driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[3]/div/input[1]')
# Experience.send_keys(' ')

# %%
search= driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div[1]/form/div/div[2]/div/button")
search.click()

# %%
r_cancel=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/div/div/button')
r_cancel.click()

# %%
job_title=[]
job_location = []
company_name = []
experience_required=[]

# %%
#scraping Job title from the given page
title_tags = driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
#scraping Job location from the given page
location_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)
    
#scraping Company name from the given page
company_tags = driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags:
    company=i.text
    company_name.append(company)    
    
#scraping Job Experience from the given page
experience_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 20 20 20 20

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'experience':experience_required})
df[:10]
# Out:
#                                                 Title        Location  \
# 0                              Technical Data Analyst   Bangalore\n+9
# 1                     opening data analyst -Bangalore       Bangalore
# 2   Data Entry Operator(data analyst work) REMOTE ...   Bangalore\n+9
# 3                             Hiring For Data Analyst   Bangalore\n+8
# 4                                 Senior Data Analyst   Bangalore\n+8
# 5                                        Data Analyst       Bangalore
# 6                      Mobility Data Analyst - IN/MKR       Bangalore
# 7                                 Senior Data Analyst       Bangalore
# 8   hiring for data entry analyst ( position data ...   Bangalore\n+9
# 9                  hiring for data entry analyst work   Bangalore\n+9
# 10  hiring for data entry analyst ( position data ...   Bangalore\n+9
# 11  Data Engineer II, Amazon WFM Tech Enterprise Data       Bangalore
# ...

# %% [markdown]
# #### Q2:Write a python program to scrape data for “Data Scientist” Job position in“Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.shine.com/
# 2. Enter “Data Scientist” in “Job title, Skills” field and enter “Bangalore” in “enter thelocation” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
driver = webdriver.Chrome()

# %%
#opening the shine page on automated chrome browser
driver.get('https://www.shine.com/')

# %%
select=driver.find_element(By.CLASS_NAME,"input")
select.click()

# %%
#entering designation and location as required in the question

designation=driver.find_element(By.CLASS_NAME,"form-control  ")
designation.send_keys('Data Scientist')

# %% [markdown]
# #### select=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[1]/div/ul/li[4]')
# select.click

# %%
cancel=driver.find_element(By.CLASS_NAME,"styledcls_body_hidden")
cancel.click()

# %%
location =driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input')
location.send_keys('Bangalore')

# %% [markdown]
# #### Experience =driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[3]/div/input[1]')
# Experience.send_keys(' ')

# %%
search= driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div[1]/form/div/div[2]/div/button")
search.click()

# %%
r_cancel=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/div/div/button')
r_cancel.click()

# %%
job_title=[]
job_location = []
company_name = []
experience_required=[]

# %%
#scraping Job title from the given page
title_tags = driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
#scraping Job location from the given page
location_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)
    
#scraping Company name from the given page
company_tags = driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags:
    company=i.text
    company_name.append(company)    
    
#scraping Job Experience from the given page
experience_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 20 20 20 20

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'experience':experience_required})
df[:10]
# Out:
#                                                Title        Location  \
# 0                                     Data Scientist       Bangalore
# 1                                 SR. DATA SCIENTIST       Bangalore
# 2                 Senior Data Scientist- ML Engineer       Bangalore
# 3                                 Data Scientist III       Bangalore
# 4       Data Scientist Hiring Fresher and Experience  Bangalore\n+17
# 5  Opening for Computer executive, data typing , ...   Bangalore\n+9
# 6                                     Data Scientist   Bangalore\n+6
# 7                         Senior Data Scientist, AWS       Bangalore
# 8                         Data Scientist Recruitment  Bangalore\n+17
# 9  Data Engineer II, Amazon WFM Tech Enterprise Data       Bangalore
#
#                     Company_name    experience
# 0              the fashion cosmo    0 to 4 Yrs
# 1  te connectivity india pvt ltd    5 to 7 Yrs
# 2              sap india pvt ltd    5 to 7 Yrs
# ...

# %% [markdown]
# #### Q3: In this question you have to scrape data using the filters available on the webpage
#  You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get the web page https://www.shine.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get.
# 6. Finally create a dataframe of the scrapeddata.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
driver = webdriver.Chrome()

# %%
#opening the shine page on automated chrome browser
driver.get('https://www.shine.com/')

# %%
select=driver.find_element(By.CLASS_NAME,"input")
select.click()

# %%
#entering designation and location as required in the question

designation=driver.find_element(By.CLASS_NAME,"form-control  ")
designation.send_keys('Data Scientist')

# %%
cancel=driver.find_element(By.CLASS_NAME,"styledcls_body_hidden")
cancel.click()

# %%
search= driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div[2]/div[2]/div[1]/form/div/div[2]/div/button")
search.click()

# %%
loc_fil=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[4]/div/div[1]/div/div[2]/div/ul/li[1]/button")
loc_fil.click()

# %%
delhi=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[4]/div/div[1]/div/div[2]/div[2]/div/div/div/div[3]/div/div/div/ul/li[7]/span/label")
delhi.click()

# %%
select=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[4]/div/div[1]/div/div[2]/div[2]/div/div/div/div[4]/button[2]")
select.click()

# %%
sal_fil=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[4]/div/div[1]/div/div[2]/div/ul/li[3]/button')
sal_fil.click()

# %%
lakhs=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[4]/div/div[1]/div/div[2]/div[2]/div/div/div/div[3]/div/div/div/ul/li[3]/span/label")
lakhs.click()

# %%
select=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[4]/div/div[1]/div/div[2]/div[2]/div/div/div/div[4]/button[2]")
select.click()

# %%
r_cancel=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[2]/div/div/button')
r_cancel.click()

# %%
job_title=[]
job_location = []
company_name = []
experience_required=[]

# %%
#scraping Job title from the given page
title_tags = driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
#scraping Job location from the given page
location_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)
    
#scraping Company name from the given page
company_tags = driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags:
    company=i.text
    company_name.append(company)    
    
#scraping Job Experience from the given page
experience_tags = driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 20 20 20 20

# %%
import pandas as pd
df = pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'experience':experience_required})
df[:10]
# Out:
#                                     Title   Location  \
# 0                          Data Scientist  Delhi\n+6
# 1                    DATA SCIENTIST DELHI      Delhi
# 2                          Data Scientist  Delhi\n+6
# 3              Apply for Data Entry Delhi      Delhi
# 4                     Data Entry Operator  Delhi\n+9
# 5                  Technical Data Analyst  Delhi\n+9
# 6                        DATA ENTRY DELHI      Delhi
# 7                      Require Data Entry      Delhi
# 8  Urgent requirement Data Entry Operator  Delhi\n+9
# 9    GIS-Utility Network Model Consultant  Delhi\n+8
#
#                              Company_name   experience
# 0                         quiscon biotech    0 to 1 Yr
# 1                     skyleaf consultants   3 to 6 Yrs
# 2                         quiscon biotech   0 to 3 Yrs
# 3                          rise placement   0 to 3 Yrs
# 4  apex trading & softech solutions hi...    0 to 1 Yr
# ...

# %% [markdown]
# #### Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 6. Brand
# 7. Product Description
# 8. Price
# The attributes which you have to scrape is ticked marked in the below image.
#
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url :https://www.flipkart.com/
# 2. Enter “sunglasses” in the search fieldwhere “search for products, brands and more” is written and
# click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the
# required data as usual.
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it.
# 5. Now scrape data from this page as usual
# 6. Repeat this until you get data for 100sunglasses.
# Note: That all of the above steps have to be done by coding only and not manually.

# %%
driver = webdriver.Chrome()

# %%
#opening the flipkart page on automated chrome browser
driver.get('https://www.flipkart.com/')

# %%
select=driver.find_element(By.XPATH,'/html/body/div[3]/div/span')
select.click()

# %%
product=driver.find_element(By.XPATH,'//input[@class="Pke_EE"]')
product.send_keys('sunglasses')

# %%
search=driver.find_element(By.XPATH,'//button[@class="_2iLD__"]')
search.click()

# %%
Brand = []
product_desc = []
price = []
discount = []

# %%
start = 0
end = 4

for page in range(start,end):
    brand_tags = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags:
    brand=i.text
    Brand.append(brand)
next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
next_button.click()
time.sleep(3) #pause webdriver for few seconds

# %%
start = 0
end = 4

for page in range(start,end):
    desc_tags = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in desc_tags:
    desc=i.text
    product_desc.append(desc)
    
for page in range(start,end):
    price_tags = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags:
    cost=i.text
    price.append(cost)    
    
for page in range(start,end):
    discount_tags = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in discount_tags:
    disc=i.text
    discount.append(disc)
    
next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
next_button.click()
time.sleep(3) #pause webdriver for few seconds

# %%
print(len(Brand))
# Out:
# 120

# %%
print(len(Brand),len(product_desc),len(price),len(discount))
# Out:
# 120 114 120 120

# %%
import pandas as pd
df = pd.DataFrame({'Brand':Brand,'Price': price,'Discount':discount})
df[:100]
# Out:
#             Brand   Price Discount
# 0          GANSTA    ₹292  85% off
# 1   VINCENT CHASE    ₹849  57% off
# 2        Fastrack    ₹499  44% off
# 3        Fastrack    ₹799  42% off
# 4       Rich Club    ₹488  62% off
# ..            ...     ...      ...
# 95      Elligator    ₹220  77% off
# 96           IRUS    ₹759  14% off
# 97  VINCENT CHASE    ₹699  65% off
# 98         PIRASO    ₹357  86% off
# 99    Eyewearlabs  ₹1,299  63% off
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market
# place=FLIPKART
# As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100reviews.
# Note: All the steps required during scraping should be done through code only and not manually.

# %%
driver = webdriver.Chrome()

# %%
#opening the flipkart page on automated chrome browser
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZE3ENS&marketplace=FLIPKART')

# %%
#select=driver.find_element(By.XPATH,'/html/body/div[3]/div/span')
#select.click()

# %%
Rating = []
Full_Review = []
Review = []

# %%
start = 0
end = 11
for page in range(start,end):
    rating_tags= driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in rating_tags:
    rating=i.text
    Rating.append(rating)
    
for page in range(start,end):
    Full_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
for i in Full_tags:
    full=i.text
    Full_Review.append(full)
    
for page in range(start,end):
    review=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
for i in review:
    rev=i.text
    Review.append(rev)

next_button= driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
next_button.click()
time.sleep(3)

# %%
print(len(Rating),len(Full_Review),len(Review))

# %%
import pandas as pd
df = pd.DataFrame({'Rating':Rating,'Full Review':Full_Review,'Heading':Review})
df[:100]
# Out:
#    Rating                                        Full Review  \
# 0       5                                        Good Camera
# 1       5                             This is amazing at all
# 2       5  Feeling awesome after getting the delivery of ...
# 3       5  Go for iPhone 11 , if confused between iPhone ...
# 4       5  Camera is awesome\nBest battery backup\nA perf...
# ..    ...                                                ...
# 95      5                        Good product 👌I love iPhone
# 96      5                                     Purple is best
# 97      5  It’s very good battery life and display and vi...
# 98      5                                          Very good
# 99      5  Awesome Battery Life...Camera clarity is too g...
#
#                 Heading
# 0   Best in the market!
# 1             Wonderful
# 2     Worth every penny
# 3             Must buy!
# 4        Classy product
# ..                  ...
# 95               Super!
# 96        Great product
# ...

# %% [markdown]
# #### Q6: Scrape data for first 100 sneakers you find whenyou visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. ProductDescription
# 3. Price
# As shown in the below image, you have to scrape the above attributes.

# %%
driver = webdriver.Chrome()

# %%
#opening the flipkart page on automated chrome browser
driver.get('https://www.flipkart.com/')

# %%
select=driver.find_element(By.XPATH,'/html/body/div[3]/div/span')
select.click()

# %%
product=driver.find_element(By.XPATH,'//input[@class="Pke_EE"]')
product.send_keys('sneakers')

# %%
search=driver.find_element(By.XPATH,'//button[@class="_2iLD__"]')
search.click()

# %%
Brand = []
product_desc = []
price = []
discount = []

# %%
start = 0
end = 4

for page in range(start,end):
    brand_tags = driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags:
    brand=i.text
    Brand.append(brand)

for page in range(start,end):
    desc_tags = driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in desc_tags:
    desc=i.text
    product_desc.append(desc)
    
for page in range(start,end):
    price_tags = driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags:
    cost=i.text
    price.append(cost)    
    
for page in range(start,end):
    discount_tags = driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in discount_tags:
    disc=i.text
    discount.append(disc)
    
next_button = driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
next_button.click()
time.sleep(3) #pause webdriver for few seconds

# %%
print(len(Brand),len(product_desc),len(price),len(discount))
# Out:
# 120 113 120 120

# %%
import pandas as pd
df = pd.DataFrame({'Brand':Brand,'Price': price,'Discount':discount})
df[:100]
# Out:
#               Brand   Price Discount
# 0              aadi    ₹279  72% off
# 1              aadi    ₹279  86% off
# 2             asian    ₹822  51% off
# 3             asian    ₹622  30% off
# 4   U.S. POLO ASSN.  ₹1,558  48% off
# ..              ...     ...      ...
# 95      kardam&sons    ₹341  73% off
# 96    PETER ENGLAND  ₹1,264  45% off
# 97         Afrojack    ₹636  83% off
# 98           BIZDOM    ₹499  66% off
# 99         WOODLAND  ₹1,751  35% off
#
# [100 rows x 3 columns]

# %% [markdown]
# #### Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Thenset CPU Type filter to “Intel Core i7” as shown in the below image:
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver = webdriver.Chrome()

# %%
#opening the amazon page on automated chrome browser
driver.get('https://www.amazon.in/')

# %%
product=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
product.send_keys('Laptops')

# %%
search=driver.find_element(By.XPATH,'//div[@class="nav-right"]')
search.click()

# %%
filter_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/span[9]/li/span/a/div')
filter_button.click()

# %%
Title = []
Ratings = [] 
Price = []

# %%
#scraping title from the given page
title_tags = driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in title_tags:
    title=i.text
    Title.append(title)
    
#scraping rating from the given page
ratings_tags = driver.find_elements(By.XPATH,'//span[@class="a-size-base puis-normal-weight-text"]')
for i in ratings_tags:
    ratings=i.text
    Ratings.append(ratings)
    
#scraping price from the given page
price_tags = driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price_tags:
    price=i.text
    Price.append(price)

# %%
print(len(Title),len(Rating),len(Price))
# Out:
# 48 110 48

# %%
import pandas as pd
df = pd.DataFrame({'Title':Title,'Price':Price})
df[:10]
# Out:
#                                                Title     Price
# 0  MSI GF63 Thin, Intel Core i7-11800H, 40CM FHD ...    66,990
# 1  ASUS Vivobook 15, Intel Core i7-12650H 12th Ge...    64,990
# 2  Dell Inspiron 5430 Laptop, Intel Core i7-1360P...    86,490
# 3  MSI GF63 Thin, Intel Core i7-11800H, 40CM FHD ...    68,829
# 4  HP Victus Gaming Laptop, 12th Gen Intel Core i...    84,990
# 5  HP Laptop 15s, 12th Gen Intel Core i7-1255U, 1...    68,990
# 6  Lenovo ThinkPad E14 Intel Core i7 12th Gen 14"...    93,990
# 7  Samsung [SmartChoice] Galaxy Book2 (NP750) Int...    79,990
# 8  MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM ...    54,990
# 9  ASUS TUF Gaming F15, 15.6-inch (39.62 cms) FHD...  1,03,625

# %% [markdown]
# #### Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpagehttps://www.azquotes.com/
# 2. Click on TopQuotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
driver = webdriver.Chrome()

# %%
#opening the azquotes page on automated chrome browser
driver.get('https://www.azquotes.com/')

# %%
top_quotes=driver.find_element(By.XPATH,'//a[@href="/top_quotes.html"]')
top_quotes.click()

# %%
Quotes = []
Author = [] 
Quote_type = []

# %%
start = 0
end = 11

for page in range(start,end):
    quote_tags = driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quote_tags:
    quote=i.text
    Quotes.append(quote)
    
for page in range(start,end):
    author_tags = driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_tags:
    author=i.text
    Author.append(author)
    
for page in range(start,end):
    type_tags = driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in type_tags:
    types=i.text
    Quote_type.append(types)
    
next_button = driver.find_element(By.XPATH,'//li[@class="next"]')
next_button.click()
time.sleep(3)

# %%
print(len(Quotes),len(Author),len(Quote_type))

# %%
import pandas as pd
df = pd.DataFrame({'Quotes':Quotes,'Author':Author,'Quote type':Quote_type})
df[:1000]
# Out:
#                                                 Quotes              Author  \
# 0    The essence of strategy is choosing what not t...      Michael Porter
# 1    One cannot and must not try to erase the past ...          Golda Meir
# 2    Patriotism means to stand by the country. It d...  Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...      Nelson Mandela
# 4    You have to love a nation that celebrates its ...        Erma Bombeck
# ..                                                 ...                 ...
# 995  Regret for the things we did can be tempered b...    Sydney J. Harris
# 996  America... just a nation of two hundred millio...  Hunter S. Thompson
# 997  For every disciplined effort there is a multip...            Jim Rohn
# 998  The spiritual journey is individual, highly pe...            Ram Dass
# 999  The mind is not a vessel to be filled but a fi...            Plutarch
#
#                                    Quote type
# ...

# %% [markdown]
# #### Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead,Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpagehttps://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make theDataFrame

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.jagranjosh.com/')

# %%
gk=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div/div/div[3]/ul/li[3]/a')
gk.click()

# %%
table=driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
table.click()

# %%
Name = []
Born_Dead = []
Term = []
Remarks = []

# %%
name_tags = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]')
for i in name_tags:
    name=i.text
    Name.append(name)
    
bd_tags = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]')
for i in bd_tags:
    borndead=i.text
    Born_Dead.append(borndead)
    
term_tags = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]')
for i in term_tags:
    term=i.text
    Term.append(term)    
    
remarks_tags = driver.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]')
for i in remarks_tags:
    rem=i.text
    Remarks.append(rem)

# %%
print(len(Name),len(Born_Dead),len(Term),len(Remarks))
# Out:
# 20 19 19 19

# %%
import pandas as pd
df = pd.DataFrame({'Name':Name[0:19],'Born-Dead':Born_Dead,'Term':Term,'Remarks':Remarks})
df
# Out:
#                            Name     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
# 18                Narendra Modi   (born 1950)
#
# ...

# %% [markdown]
# #### Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e.
# Car name and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to type in the search bar ’50 most expensive cars’
# 3. Then click on 50 most expensive carsin the world..
# 4. Then scrap the mentioned data and make the dataframe.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.motor1.com/')

# %%
search=driver.find_element(By.XPATH,'//div[@class="m1-search-panel"]')
search.click()

# %%
cars=driver.find_element(By.XPATH,'//input[@class="m1-search-panel-input m1-search-form-text"]')
cars.send_keys('50 most expensive cars')

# %%
search=driver.find_element(By.XPATH,'//button[@class="m1-search-panel-button m1-search-form-button-animate icon-search-svg"]')
search.click()

# %%
lists=driver.find_element(By.XPATH,'//a[@href="/features/308149/most-expensive-new-cars-ever/"]')
lists.click()

# %%
Car_Name=[]
Price=[]

# %%
carname = driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in carname:
    name=i.text
    Car_Name.append(name)
    
price = driver.find_elements(By.XPATH,'//div[@class="postBody description e-content"]/p/strong')
for i in price:
    cost=i.text
    Price.append(cost)

# %%
print(len(Car_Name),len(Price))
# Out:
# 51 50

# %%
import pandas as pd
df = pd.DataFrame({'Car Name':Car_Name[0:50],'Price':Price})
df
# Out:
#                               Car Name                        Price
# 0                  Aston Martin Valour          Price: $1.5 Million
# 1                         McLaren Elva          Price: $1.7 Million
# 2                          Czinger 21C          Price: $1.7 Million
# 3                        Ferrari Monza          Price: $1.7 Million
# 4                   Gordon Murray T.33          Price: $1.7 Million
# 5                    Koenigsegg Gemera          Price: $1.7 Million
# 6                          Zenvo TSR-S          Price: $1.7 Million
# 7                   Hennessey Venom F5          Price: $1.8 Million
# 8                      Bentley Bacalar          Price: $1.9 Million
# 9        Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 10              Bentley Mulliner Batur          Price: $2.0 Million
# 11                        Deus Vayanne          Price: $2.0 Million
# 12                         SSC Tuatara          Price: $2.0 Million
# ...
